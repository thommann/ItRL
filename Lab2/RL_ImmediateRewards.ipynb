# %% [markdown]
# ## THE TASK
#
# We will use again the MNIST datasets, but in this case we will train two percpetrons, one with supervised learning and the other through RL.
# For the training loop with RL, a reward of 1 is delivered if the correct action (the output that corresponds to the input image) is taken, and the reward will be zero otherwise. This is an example of an environment with immediate rewards, because the agent makes an action and receives a reward after presentation of an input image.
# The difference between RL and supervised learning is depicted below.
#
# <img src="Supervised_RL.jpg" width="800" height="500">

# %%
import numpy as np;
import numpy.matlib 
import math
import matplotlib.pyplot as plt
import csv

# %%
# Load the MNIST dataset:

from scipy.io import loadmat

mnist = loadmat('MNIST.mat')

# Read the train set
x_train = mnist['x_train']
# Read the train labels
trainlabels = mnist['trainlabels']

# Read the test set
x_test = mnist['x_test']
# Read the test labels
testlabels = mnist['testlabels']

#We select the data for N_class (in this case 5) classes that we want to classify

N_class=5

Index_tr=[]
Index_te=[]

for i in range(N_class):
    
    #Find the indexes of the training set corresponding to class i
    ind_tr=np.where(trainlabels==i)[0]
    #Find the indexes of the test set corresponding to class i
    ind_te=np.where(testlabels==i)[0]
    
    # Append the training indexes in a list
    Index_tr.append(ind_tr)
    # Append the testing indexes in a list
    Index_te.append(ind_te)

# Reshape the lists to be a 1-d array    
Index_tr=np.concatenate(Index_tr,axis=0)
Index_te=np.concatenate(Index_te,axis=0)

# Create a training set and a test set with data belonging to the classes considered only
X_tr=np.copy(x_train[Index_tr,:])
X_te=np.copy(x_test[Index_te,:])

# Compute the size of the train and test datasets
N_tr=np.shape(Index_tr)[0]
N_te=np.shape(Index_te)[0]

# Create one-hot encoding labels for train and test datasets
Y_tr=np.zeros([N_tr,N_class])
Y_te=np.zeros([N_te,N_class])

for i in range(N_tr):
    
    Y_tr[i,int(trainlabels[Index_tr[i]])]=1

for i in range(N_te):

    Y_te[i,int(testlabels[Index_te[i]])]=1

# %%
# Let's plot some examples

N_image_r=3

fig, axs = plt.subplots(N_image_r, N_image_r,figsize=(10,8))

for i in range(N_image_r):
    for j in range(N_image_r):
        
        random_ind=np.random.randint(0,N_tr)
        example_image=np.reshape(X_tr[random_ind],(28,28))
        
        axs[i,j].imshow(example_image.T)
        axs[i,j].title.set_text(np.array2string(Y_tr[random_ind,:]))

plt.tight_layout()

# %% [markdown]
# ## Matrix multiplication, avoiding for loops
#
# For this exercise, we will consider a different method to compute the network's activities and the gradients.
# In the previous lab (Lab1), we have used for loops to compute the response of the system for each sample in the minibatch.
# Now, we will be using matrix multiplications.
#
# As in standard tools like Tensorflow and Pytorch, the first dimension will always be the dimension containing the different samples in the minibatch. Thus, our input $\mathbf{x}$ will be of shape $[batch_{size},784]$ for the minibatch considered.
#
# Then, performing matrix multiplications $\mathbf{x}\mathbf{W}$ (notice that the weights are of shape $[784,N_{class}]$) we will get outputs of shapes $[batch_{size},N_{class}]$ for all the samples in the minibatch at once.
#
# Finally, we will perform the updates of the parameters in a similar fashion.

# %%
## Definition of the epsilon-greedy policy. Notice that the shape of the Qvalues (input to the function) should be 
## [batch_size,N_actions]

def EpsilonGreedy_Policy(Qvalues, epsilon):
    

    N_class=np.shape(Qvalues)[1]
    batch_size=np.shape(Qvalues)[0]

    rand_values=np.random.uniform(0,1,[batch_size])

    rand_a=rand_values<epsilon
    a=np.zeros([batch_size,N_class])

    for i in range(batch_size):

        if rand_a[i]==True:

            a[i,np.random.randint(0,N_class)]=1

        else:

            a[i,np.argmax(Qvalues[i])]=1
            
    return a

## What is the probability of selecting the best action?
## Theoretically, it is (1-epsilon)+epsilon*1/N_class, where the first term corresponds to selecting the greedy action, while the
## second term corresponds to select a random action that corresponds to the greedy action
## Let' s check that this is true

epsilon=0.4

# Generate 100000 Q-values
Qvalues=np.random.randn(100000,N_class)

# Greedy policy
greedy=np.argmax(Qvalues,1)

# Epsilon-greedy policy
actions=EpsilonGreedy_Policy(Qvalues,epsilon)

print('Theoretical: ', 1/N_class*epsilon+(1-epsilon), 'Model: ',  np.mean(greedy==np.argmax(actions,1)))
# Out:
# Theoretical:  0.6799999999999999 Model:  0.68002

# %%
## Hyperparameters

N_minibatch=10000
batch_size=10

n_input=np.shape(X_tr)[1]

eta=0.0005
epison=0.4

# %%
## Training Loop

## WE HAVE TWO PERCEPTRONS, ONE TRAINED WITH RL AND THE OTHER WITH SUPERVISED LEARNING
## YOU WILL HAVE TO TRAIN THE RL NETWORK AND PLOT THE AVERAGE REWARD AS TRAINING PROGRESSES
## THE CODE FOR THE SUPERVISED LEARNING NETWORK HAS BEEN GIVEN
## PLEASE NOTE THAT IN RL YOU NEED TO UPDATE ONLY THE PARAMETERS CORRESPONDING TO THE ACTIONS TAKEN

# Let's initialise the weights and the bias for the perceptron  
W=np.random.randn(n_input,N_class)/np.sqrt(n_input)
b=np.zeros([1,N_class])

# Let's create a copy of the parameters to be optimised with supervised learning
W_sp=np.copy(W)
b_sp=np.copy(b)


## Define after how many minibatches we will compute the performance 
N_check=100

## Number of times in which we will compute the performance
N_perf=int(np.round(N_minibatch/N_check))

Accuracy=np.zeros([2,N_perf])
Average_R=np.zeros([2,N_perf])

for n in range(N_minibatch):
        
    ## Let's select batch_size training images, which are sampled randomly from the dataset
    
    batch_ind=np.random.randint(0,N_tr,[batch_size])
    
    # The input, of shape [batch_size,784]
    x=np.copy(X_tr[batch_ind,:])
    
    # The desired output (in one hot encoding), of shape [batch_size,3]
    y_true=np.copy(Y_tr[batch_ind,:])
    
    # SUPERVISED LEARNING
    
    # Computation of the network's output for all the sampled images  
    # The outputs should have shape [batch_size,N_class], that is N_class outpit dimensions for all the batch_size sampled images
    # Given that x has shape [batch_size,784] and W has shape [batch_size,N_class], np.matmul(x,W) has shape [batch_size,N_class]
    # To add the bias which has shape [1,N_class], we need to replicate its value batch_size times across the firs dimension
    y=np.matmul(x,W_sp)+np.tile(b_sp,[batch_size,1])
    
    delta_sp=(y_true-y)
    
    # np.transpose(x) is of size [784,batch_size], while delta is of size [batch_size,N_class]. 
    # Their product is of size [784,N_class] and gives us exatly the delta for the weights, summing the samples in the minibatch.
    delta_W_sp=np.matmul(np.transpose(x),delta_sp)
    
    # delta_b is the sum of the delta [minbatch,N_class] across the minibatch, to obtain the shape of the bias [1,N_class]
    delta_b_sp=np.expand_dims(np.sum(delta_sp,0),0)
    
    W_sp=W_sp+eta*delta_W_sp
    b_sp=b_sp+eta*delta_b_sp
    
    # REINFORCEMENT LEARNING
    
    # FILL YOUR CODE FOR REINFORCEMENT LEARNING
    
    
    # Every N_check iterations we compute the performance of the two networks, one trained with supervised learning and the other 
    # with RL. For RL, we will use the greedy policy while testing, to exploit and report the accuracy.
    if n%N_check==0:
        
        x=np.copy(X_tr)
        y_true=np.copy(Y_tr)
        
        ## SUPERVISED LEARNING
        
        y=np.matmul(x,W_sp)+np.tile(b_sp,[N_tr,1])
        selected_outs=np.argmax(y,1)
        
        Correct_tr=np.int32(np.argmax(y_true,1)==selected_outs)
        
        ## REINFORCEMENT LEARNING
        ## FILL YOUR CODE TO COMPUTE THE RL PERFORMANCE ON THE TRAINING SET
        
        
        ## SUPERVISED LEARNING
        
        x=np.copy(X_te)
        y_true=np.copy(Y_te)
        
        y=np.matmul(x,W_sp)+np.tile(b_sp,[N_te,1])
        selected_outs=np.argmax(y,1)
        
       
        Correct_te=np.int32(np.argmax(y_true,1)==selected_outs)
        
        ## REINFORCEMENT LEARNING
        ## FILL YOUR CODE TO COMPUTE THE RL PERFORMANCE ON THE TRAINING SET
        
        print('Minibatch number ',n, 'SUPERVISED LEARNING: Accuracy for Train and Test ',np.mean(Correct_tr),np.mean(Correct_te))

    
        ind_save=int(n/N_check)
        Accuracy[0,ind_save]=np.mean(Correct_tr)
        Accuracy[1,ind_save]=np.mean(Correct_te)
        
        # SAVE THE AVERAGE REWARDS
# Out:
# Minibatch number  0 SUPERVISED LEARNING: Accuracy for Train and Test  0.18332461759707153 0.1899202179412337
# Minibatch number  100 SUPERVISED LEARNING: Accuracy for Train and Test  0.8360243169041705 0.8488032691185056
# Minibatch number  200 SUPERVISED LEARNING: Accuracy for Train and Test  0.8849195973329848 0.8914185639229422
# Minibatch number  300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9091711334815008 0.9194395796847635
# Minibatch number  400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9133546868871748 0.9217746643315821
# Minibatch number  500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9219505817753955 0.9326717260167348
# Minibatch number  600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9216237416655771 0.9291690990465071
# Minibatch number  700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9214930056216499 0.9283907374975676
# Minibatch number  800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9264282912799059 0.9315041836933255
# Minibatch number  900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9258072950712511 0.9303366413699163
# Minibatch number  1000 SUPERVISED LEARNING: Accuracy for Train and Test  0.92489214276376 0.9297528702082117
# Minibatch number  1100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9298601124329978 0.9359797625997276
# Minibatch number  1200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9314289449601255 0.9340338587273789
# Minibatch number  1300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9358086024316904 0.9435687877018876
# Minibatch number  1400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9378350111125637 0.9460984627359409
# Minibatch number  1500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9314289449601255 0.9334500875656743
# Minibatch number  1600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9367891227611452 0.944347149250827
# Minibatch number  1700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9371159628709635 0.941233703055069
# Minibatch number  1800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9392731075957641 0.9439579684763573
# Minibatch number  1900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9384233233102366 0.942985016540183
# Minibatch number  2000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9357759184207086 0.9392877991827204
# Minibatch number  2100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9419531964962741 0.9480443666082895
# Minibatch number  2200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9358739704536541 0.9379256664720763
# Minibatch number  2300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9386194273761276 0.9416228838295388
# Minibatch number  2400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9405151000130736 0.9476551858338198
# Minibatch number  2500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9413322002876193 0.9466822338976455
# Minibatch number  2600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9434239769904562 0.9494064993189336
# Minibatch number  2700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9413648842986011 0.9513524031912823
# Minibatch number  2800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9412668322656557 0.9470714146721152
# Minibatch number  2900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9409073081448556 0.9453201011870014
# Minibatch number  3000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9410380441887829 0.9445417396380619
# Minibatch number  3100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9436854490783109 0.9513524031912823
# Minibatch number  3200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9413648842986011 0.9449309204125316
# Minibatch number  3300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9424761406719833 0.9451255107997665
# Minibatch number  3400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9411360962217283 0.9447363300252968
# Minibatch number  3500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9375735390247091 0.9392877991827204
# Minibatch number  3600 SUPERVISED LEARNING: Accuracy for Train and Test  0.942149300562165 0.9457092819614711
# Minibatch number  3700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9418878284743104 0.948822728157229
# Minibatch number  3800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9438161851222382 0.9492119089316988
# Minibatch number  3900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9447313374297294 0.9499902704806382
# Minibatch number  4000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9402863119362008 0.9425958357657132
# Minibatch number  4100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9455157536932932 0.9521307647402218
# Minibatch number  4200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9435547130343835 0.9453201011870014
# Minibatch number  4300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9413322002876193 0.9437633780891224
# Minibatch number  4400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9437508171002745 0.950379451255108
# Minibatch number  4500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9448947574846385 0.9511578128040474
# Minibatch number  4600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9444371813308929 0.9480443666082895
# Minibatch number  4700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9444371813308929 0.9523253551274568
# Minibatch number  4800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9437835011112564 0.9468768242848803
# Minibatch number  4900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9451235455615113 0.9501848608678731
# Minibatch number  5000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9459079618250752 0.9505740416423428
# Minibatch number  5100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9455157536932932 0.9496010897061685
# Minibatch number  5200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9446986534187476 0.9466822338976455
# Minibatch number  5300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9475748463851484 0.9536874878381008
# Minibatch number  5400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9429990848476925 0.9447363300252968
# Minibatch number  5500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9461040658909662 0.9536874878381008
# Minibatch number  5600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9415283043535103 0.9445417396380619
# Minibatch number  5700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9471172702314028 0.9536874878381008
# Minibatch number  5800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9395672636946006 0.939871570344425
# Minibatch number  5900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9418551444633285 0.9414282934423039
# Minibatch number  6000 SUPERVISED LEARNING: Accuracy for Train and Test  0.945744541770166 0.9509632224168126
# Minibatch number  6100 SUPERVISED LEARNING: Accuracy for Train and Test  0.943097136880638 0.9433741973146527
# Minibatch number  6200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9471826382533665 0.9515469935785172
# Minibatch number  6300 SUPERVISED LEARNING: Accuracy for Train and Test  0.94688848215453 0.9523253551274568
# Minibatch number  6400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9429664008367107 0.9427904261529481
# Minibatch number  6500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9427702967708197 0.9449309204125316
# Minibatch number  6600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9426722447378743 0.9441525588635922
# Minibatch number  6700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9448620734736567 0.9497956800934034
# Minibatch number  6800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9460713818799843 0.9521307647402218
# Minibatch number  6900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9453523336383841 0.948822728157229
# Minibatch number  7000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9466270100666754 0.9515469935785172
# Minibatch number  7100 SUPERVISED LEARNING: Accuracy for Train and Test  0.947836318473003 0.953492897450866
# Minibatch number  7200 SUPERVISED LEARNING: Accuracy for Train and Test  0.946136749901948 0.9542712589998054
# Minibatch number  7300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9475748463851484 0.9531037166763962
# Minibatch number  7400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9441430252320565 0.9478497762210547
# Minibatch number  7500 SUPERVISED LEARNING: Accuracy for Train and Test  0.945940645836057 0.9497956800934034
# Minibatch number  7600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9483592626487123 0.9532983070636311
# Minibatch number  7700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9477382664400575 0.9523253551274568
# Minibatch number  7800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9496339390770036 0.9569955244210936
# Minibatch number  7900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9483919466596941 0.9532983070636311
# Minibatch number  8000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9456464897372205 0.9484335473827593
# Minibatch number  8100 SUPERVISED LEARNING: Accuracy for Train and Test  0.944600601385802 0.9476551858338198
# Minibatch number  8200 SUPERVISED LEARNING: Accuracy for Train and Test  0.9466596940776573 0.9509632224168126
# Minibatch number  8300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9454830696823114 0.9460984627359409
# Minibatch number  8400 SUPERVISED LEARNING: Accuracy for Train and Test  0.946496274022748 0.9525199455146915
# Minibatch number  8500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9438161851222382 0.944347149250827
# Minibatch number  8600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9473133742972938 0.9507686320295777
# Minibatch number  8700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9451562295724931 0.9480443666082895
# Minibatch number  8800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9480651065498757 0.9544658493870403
# Minibatch number  8900 SUPERVISED LEARNING: Accuracy for Train and Test  0.9467904301215845 0.9496010897061685
# Minibatch number  9000 SUPERVISED LEARNING: Accuracy for Train and Test  0.9455811217152569 0.9455146915742363
# Minibatch number  9100 SUPERVISED LEARNING: Accuracy for Train and Test  0.9450581775395477 0.9505740416423428
# Minibatch number  9200 SUPERVISED LEARNING: Accuracy for Train and Test  0.94688848215453 0.9484335473827593
# Minibatch number  9300 SUPERVISED LEARNING: Accuracy for Train and Test  0.9456791737482024 0.9486281377699942
# Minibatch number  9400 SUPERVISED LEARNING: Accuracy for Train and Test  0.9475421623741666 0.9548550301615101
# Minibatch number  9500 SUPERVISED LEARNING: Accuracy for Train and Test  0.9492417309452216 0.9558279820976844
# Minibatch number  9600 SUPERVISED LEARNING: Accuracy for Train and Test  0.9462674859458753 0.9494064993189336
# Minibatch number  9700 SUPERVISED LEARNING: Accuracy for Train and Test  0.9472153222643482 0.9513524031912823
# Minibatch number  9800 SUPERVISED LEARNING: Accuracy for Train and Test  0.9486207347365668 0.9529091262891614
# Minibatch number  9900 SUPERVISED LEARNING: Accuracy for Train and Test  0.944796705451693 0.9453201011870014

# %%
fig, axs = plt.subplots(1,figsize=(8,6))

plt.plot(np.arange(0,N_perf)*N_check,Accuracy[1,:],'b')

# PLOT THE RL AVERAGE REWARD

plt.xlabel('Minibath #')
plt.ylabel('Accuracy (Supervised) and Average reward (Reinforcement)')
# Out:
# Text(0, 0.5, 'Accuracy (Supervised) and Average reward (Reinforcement)')

# %% [markdown]
# ## Final exercises
#
# 1. Given the performance of the RL model after training using a greedy policy, what is the accuracy for an epsilon greedy policy?
#
#
# 2. If you increase the number of output classes, how will RL perform in comparison to supervised learning?
#
#
# 3. Use Adam for the simulation with ten classes
